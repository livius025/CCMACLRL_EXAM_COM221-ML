# %% [markdown]
# <a href="https://colab.research.google.com/github/livius025/CCMACLRL_EXAM_COM221-ML/blob/main/Midterm_Exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
dataset_url = 'train.csv'
df = pd.read_csv(dataset_url)

# %%
test_url = 'test.csv'
dt = pd.read_csv(test_url)

# %%
sample_submission_url = 'sample_submission.csv'
sf=pd.read_csv(sample_submission_url)

# %%
df.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188533 entries, 0 to 188532
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            188533 non-null  int64
#  1   brand         188533 non-null  object
#  2   model         188533 non-null  object
#  3   model_year    188533 non-null  int64
#  4   milage        188533 non-null  int64
#  5   fuel_type     183450 non-null  object
#  6   engine        188533 non-null  object
#  7   transmission  188533 non-null  object
#  8   ext_col       188533 non-null  object
#  9   int_col       188533 non-null  object
#  10  accident      186081 non-null  object
#  11  clean_title   167114 non-null  object
#  12  price         188533 non-null  int64
# dtypes: int64(4), object(9)
# memory usage: 18.7+ MB

# %%
df.isnull().sum()
# Out:
# id                  0
# brand               0
# model               0
# model_year          0
# milage              0
# fuel_type        5083
# engine              0
# transmission        0
# ext_col             0
# int_col             0
# accident         2452
# clean_title     21419
# price               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id              0
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
df.describe()
# Out:
#                   id     model_year         milage         price
# count  162610.000000  162610.000000  162610.000000  1.626100e+05
# mean    94197.039137    2015.158822   71105.487086  4.081699e+04
# std     54467.770815       5.699531   50157.874111  7.653857e+04
# min         0.000000    1974.000000     100.000000  2.000000e+03
# 25%     47026.250000    2012.000000   29000.000000  1.570000e+04
# 50%     94139.000000    2016.000000   64300.000000  2.850000e+04
# 75%    141421.750000    2019.000000  101000.000000  4.699900e+04
# max    188532.000000    2024.000000  405000.000000  2.954083e+06

# %%
df.sample(20)
# Out:
#             id          brand                   model  model_year  milage  \
# 182787  182787            GMC      Sierra 3500 Denali        2019   75000
# 162705  162705       INFINITI               QX80 Base        2016  106500
# 49203    49203  Mercedes-Benz  AMG CLA 45 Base 4MATIC        2019   48700
# 9011      9011     Mitsubishi     Lancer Sportback ES        2011  156111
# 155603  155603         Toyota     Camry Solara SLE V6        2007   37216
# 80578    80578            BMW                 M6 Base        2016   70582
# 109381  109381      Chevrolet              Camaro 2SS        2015   91545
# 107816  107816           Ford       Shelby GT350 Base        2018   77000
# 47172    47172  Mercedes-Benz    AMG C 43 Base 4MATIC        2017   40000
# 176300  176300          Lexus             ES 350 Base        2010  131100
# 149206  149206        Bentley     Continental GT V8 S        2022   27608
# 27180    27180            BMW            328 i xDrive        2015  109330
# ...

# %%
df.isnull().sum()
# Out:
# id              0
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
#drop_col=['id']
#df.drop( drop_col, inplace=True, axis=1)

#object_column = df.select_dtypes(include=['object']).columns
#df[object_column]

# %% [markdown]
# this adds the new feture to check if it is luxury

# %%
luxury_brands = [
'MINI',
'Lincoln',
'Genesis',
'Mercedes-Benz',
'Audi',
'BMW',
'Tesla',
'Cadillac',
'Land',
'Volvo',
'Rivian',
'Porsche',
'McLaren',
'Lexus',
'Jaguar',
'INFINITI',
'Rolls-Royce',
'Maserati',
'Bentley',
'Ferrari',
'Aston',
'Lamborghini',
'Lucid',
'Lotus',
'Karma',
'Bugatti',
'Polestar',
'Maybach'
]

df['is_luxury'] = np.where(df['brand'].isin(luxury_brands), 'YES', 'NO')
df
# Out:
#             id          brand                     model  model_year  milage  \
# 0            0           MINI             Cooper S Base        2007  213000
# 1            1        Lincoln                     LS V8        2002  143250
# 2            2      Chevrolet         Silverado 2500 LT        2002  136731
# 3            3        Genesis          G90 5.0 Ultimate        2017   19500
# 4            4  Mercedes-Benz               Metris Base        2021    7388
# ...        ...            ...                       ...         ...     ...
# 188527  188527      Chevrolet                Camaro Z28        1999  110000
# 188528  188528       Cadillac     Escalade ESV Platinum        2017   49000
# 188529  188529  Mercedes-Benz  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530  Mercedes-Benz    AMG GLC 63 Base 4MATIC        2021   13650
# 188532  188532        Porsche                Macan Base        2016   59500
#
# ...

# %%
df.head()
# Out:
#    id          brand              model  model_year  milage      fuel_type  \
# 0   0           MINI      Cooper S Base        2007  213000       Gasoline
# 1   1        Lincoln              LS V8        2002  143250       Gasoline
# 2   2      Chevrolet  Silverado 2500 LT        2002  136731  E85 Flex Fuel
# 3   3        Genesis   G90 5.0 Ultimate        2017   19500       Gasoline
# 4   4  Mercedes-Benz        Metris Base        2021    7388       Gasoline
#
#                                               engine  \
# 0       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# 1       252.0HP 3.9L 8 Cylinder Engine Gasoline Fuel
# 2  320.0HP 5.3L 8 Cylinder Engine Flex Fuel Capab...
# 3       420.0HP 5.0L 8 Cylinder Engine Gasoline Fuel
# 4       208.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col  \
# 0                             A/T  Yellow    Gray
# 1                             A/T  Silver   Beige
# ...

# %% [markdown]
# split

# %%
x = df.drop(['ext_col','int_col'],inplace=True, axis=1)
x

# %% [markdown]
# convertion to categorical

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder




# Initialize label encoders for each categorical column
le_brand = LabelEncoder()
le_fuel_type = LabelEncoder()
le_transmission = LabelEncoder()
le_accident = LabelEncoder()
le_luxury = LabelEncoder()

# Apply label encoding to convert the strings to integers
df['brand'] = le_brand.fit_transform(df['brand'])
df['fuel_type'] = le_fuel_type.fit_transform(df['fuel_type'])
df['transmission'] = le_transmission.fit_transform(df['transmission'])
df['accident'] = le_accident.fit_transform(df['accident'])
df['is_luxury'] = le_luxury.fit_transform(df['is_luxury'])

# Print the updated DataFrame
print(df)
# Out:
#             id  brand                     model  model_year  milage  \
# 0            0     31             Cooper S Base        2007  213000
# 1            1     28                     LS V8        2002  143250
# 2            2      9         Silverado 2500 LT        2002  136731
# 3            3     16          G90 5.0 Ultimate        2017   19500
# 4            4     36               Metris Base        2021    7388
# ...        ...    ...                       ...         ...     ...
# 188527  188527      9                Camaro Z28        1999  110000
# 188528  188528      8     Escalade ESV Platinum        2017   49000
# 188529  188529     36  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530     36    AMG GLC 63 Base 4MATIC        2021   13650
# 188532  188532     43                Macan Base        2016   59500
#
#         fuel_type                                             engine  \
# 0               2       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# ...

# %%
df
# Out:
#             id  brand                     model  model_year  milage  \
# 0            0     31             Cooper S Base        2007  213000
# 1            1     28                     LS V8        2002  143250
# 2            2      9         Silverado 2500 LT        2002  136731
# 3            3     16          G90 5.0 Ultimate        2017   19500
# 4            4     36               Metris Base        2021    7388
# ...        ...    ...                       ...         ...     ...
# 188527  188527      9                Camaro Z28        1999  110000
# 188528  188528      8     Escalade ESV Platinum        2017   49000
# 188529  188529     36  AMG C 43 AMG C 43 4MATIC        2018   28600
# 188530  188530     36    AMG GLC 63 Base 4MATIC        2021   13650
# 188532  188532     43                Macan Base        2016   59500
#
#         fuel_type                                             engine  \
# 0               2       172.0HP 1.6L 4 Cylinder Engine Gasoline Fuel
# ...

# %%
drop_col=['model', 'engine', 'clean_title']
df.drop( drop_col, inplace=True, axis=1)

# %%
df
# Out:
#             id  brand  model_year  milage  fuel_type  transmission  accident  \
# 0            0     31        2007  213000          2            38         1
# 1            1     28        2002  143250          2            38         0
# 2            2      9        2002  136731          1            38         1
# 3            3     16        2017   19500          2            49         1
# 4            4     36        2021    7388          2            23         1
# ...        ...    ...         ...     ...        ...           ...       ...
# 188527  188527      9        1999  110000          2            38         1
# 188528  188528      8        2017   49000          2            49         1
# 188529  188529     36        2018   28600          2            31         0
# 188530  188530     36        2021   13650          2            23         1
# 188532  188532     43        2016   59500          2            49         1
#
#         price  is_luxury
# ...

# %%
#df['brand'] = df['brand'].astype(float)

# %%
df.head()
# Out:
#    id  brand  model_year  milage  fuel_type  transmission  accident  price  \
# 0   0     31        2007  213000          2            38         1   4200
# 1   1     28        2002  143250          2            38         0   4999
# 2   2      9        2002  136731          1            38         1  13900
# 3   3     16        2017   19500          2            49         1  45000
# 4   4     36        2021    7388          2            23         1  97500
#
#    is_luxury
# 0          1
# 1          1
# 2          0
# 3          1
# 4          1

# %%
from sklearn.model_selection import train_test_split

y_scaled = df['price']

x = df.drop(columns=['price'])

X_train, X_test, y_train, y_test = train_test_split(x, y_scaled, test_size=0.2, random_state=42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (130088, 8)
# (32522, 8)
# (130088,)
# (32522,)

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
LinearRegression()
# Out:
# LinearRegression()

# %%
y_pred_train = linear_reg.predict(X_train)

# Reshape X_test to match X_train


y_pred_test = linear_reg.predict(X_test)

# %%
# Evaluate the model
train_mse = mean_squared_error(y_train, y_pred_train, squared=False)
test_mse = mean_squared_error(y_test, y_pred_test, squared=False)
train_r2 = r2_score(y_train, y_pred_train)
test_r2 = r2_score(y_test, y_pred_test)

print(f"Training MSE: {train_mse}")
print(f"Testing MSE: {test_mse}")
print(f"Training R2 Score: {train_r2}")
print(f"Testing R2 Score: {test_r2}")
# Out:
# Training MSE: 71446.53076782667
# Testing MSE: 79597.17790306633
# Training R2 Score: 0.0897276130279675
# Testing R2 Score: 0.07628934770569851

# %%
dt.head()
# Out:
#        id brand                 model  model_year  milage fuel_type  \
# 0  188533  Land        Rover LR2 Base        2015   98000  Gasoline
# 1  188534  Land     Rover Defender SE        2020    9142    Hybrid
# 2  188535  Ford    Expedition Limited        2022   28121  Gasoline
# 3  188536  Audi         A6 2.0T Sport        2016   61258  Gasoline
# 4  188537  Audi  A6 2.0T Premium Plus        2018   59000  Gasoline
#
#                                               engine        transmission  \
# 0       240.0HP 2.0L 4 Cylinder Engine Gasoline Fuel         6-Speed A/T
# 1  395.0HP 3.0L Straight 6 Cylinder Engine Gasoli...         8-Speed A/T
# 2                    3.5L V6 24V PDI DOHC Twin Turbo  10-Speed Automatic
# 3                                     2.0 Liter TFSI           Automatic
# 4       252.0HP 2.0L 4 Cylinder Engine Gasoline Fuel                 A/T
#
#            ext_col int_col       accident clean_title
# 0            White   Beige  None reported         Yes
# ...

# %%
luxury_brands = [
'MINI',
'Lincoln',
'Genesis',
'Mercedes-Benz',
'Audi',
'BMW',
'Tesla',
'Cadillac',
'Land',
'Volvo',
'Rivian',
'Porsche',
'McLaren',
'Lexus',
'Jaguar',
'INFINITI',
'Rolls-Royce',
'Maserati',
'Bentley',
'Ferrari',
'Aston',
'Lamborghini',
'Lucid',
'Lotus',
'Karma',
'Bugatti',
'Polestar',
'Maybach'
]

dt['is_luxury'] = np.where(dt['brand'].isin(luxury_brands), 'YES', 'NO')
dt
# Out:
#             id          brand                   model  model_year  milage  \
# 0       188533           Land          Rover LR2 Base        2015   98000
# 1       188534           Land       Rover Defender SE        2020    9142
# 2       188535           Ford      Expedition Limited        2022   28121
# 3       188536           Audi           A6 2.0T Sport        2016   61258
# 4       188537           Audi    A6 2.0T Premium Plus        2018   59000
# ...        ...            ...                     ...         ...     ...
# 125685  314218  Mercedes-Benz  GL-Class GL 450 4MATIC        2014   83315
# 125686  314219           Audi          Q7 55 Prestige        2019   29336
# 125687  314220           Audi    A6 3.0T Premium Plus        2012   77634
# 125688  314221           Audi         Q7 3.0T Premium        2012  112000
# 125689  314222      Chevrolet                Tahoe LT        2018   66840
#
#        fuel_type                                             engine  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder




# Initialize label encoders for each categorical column
le_brand = LabelEncoder()
le_fuel_type = LabelEncoder()
le_transmission = LabelEncoder()
le_accident = LabelEncoder()
le_luxury = LabelEncoder()

# Apply label encoding to convert the strings to integers
dt['brand'] = le_brand.fit_transform(dt['brand'])
dt['fuel_type'] = le_fuel_type.fit_transform(dt['fuel_type'])
dt['transmission'] = le_transmission.fit_transform(dt['transmission'])
dt['accident'] = le_accident.fit_transform(dt['accident'])
dt['is_luxury'] = le_luxury.fit_transform(dt['is_luxury'])
# Print the updated DataFrame
print(dt)
# Out:
#             id  brand                   model  model_year  milage  fuel_type  \
# 0       188533     26          Rover LR2 Base        2015   98000          2
# 1       188534     26       Rover Defender SE        2020    9142          3
# 2       188535     14      Expedition Limited        2022   28121          2
# 3       188536      3           A6 2.0T Sport        2016   61258          2
# 4       188537      3    A6 2.0T Premium Plus        2018   59000          2
# ...        ...    ...                     ...         ...     ...        ...
# 125685  314218     36  GL-Class GL 450 4MATIC        2014   83315          2
# 125686  314219      3          Q7 55 Prestige        2019   29336          2
# 125687  314220      3    A6 3.0T Premium Plus        2012   77634          2
# 125688  314221      3         Q7 3.0T Premium        2012  112000          2
# 125689  314222      9                Tahoe LT        2018   66840          2
#
# ...

# %%
x = dt.drop(['ext_col','int_col'],inplace=True, axis=1)
x

# %%
drop_col=['model', 'engine', 'clean_title']
dt.drop( drop_col, inplace=True, axis=1)

# %%
dt
# Out:
#             id  brand  model_year  milage  fuel_type  transmission  accident  \
# 0       188533     26        2015   98000          2            16         1
# 1       188534     26        2020    9142          3            31         1
# 2       188535     14        2022   28121          2             3         1
# 3       188536      3        2016   61258          2            39         1
# 4       188537      3        2018   59000          2            38         1
# ...        ...    ...         ...     ...        ...           ...       ...
# 125685  314218     36        2014   83315          2            23         1
# 125686  314219      3        2019   29336          2            39         1
# 125687  314220      3        2012   77634          2            38         1
# 125688  314221      3        2012  112000          2            38         1
# 125689  314222      9        2018   66840          2            38         1
#
#         is_luxury
# 0               1
# ...

# %%
# from sklearn.model_selection import train_test_split

# y_scaled = dt['price']

# x = dt.drop(columns=['price'])

# X_train, X_test, y_train, y_test = train_test_split(x, y_scaled, test_size=0.2, random_state=42)

# print(X_train.shape)
# print(X_test.shape)
# print(y_train.shape)
# print(y_test.shape)

# %%
from sklearn.linear_model import LinearRegression

linear_reg = LinearRegression()
linear_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_train = linear_reg.predict(X_train)

# Reshape X_test to match X_train


y_pred_test = linear_reg.predict(X_test)

# %%
# Evaluate the model
train_mse = mean_squared_error(y_train, y_pred_train, squared=False)
test_mse = mean_squared_error(y_test, y_pred_test, squared=False)
train_r2 = r2_score(y_train, y_pred_train)
test_r2 = r2_score(y_test, y_pred_test)

print(f"Training MSE: {train_mse}")
print(f"Testing MSE: {test_mse}")
print(f"Training R2 Score: {train_r2}")
print(f"Testing R2 Score: {test_r2}")
# Out:
# Training MSE: 71446.53076782667
# Testing MSE: 79597.17790306633
# Training R2 Score: 0.0897276130279675
# Testing R2 Score: 0.07628934770569851

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            125690 non-null  int64
#  1   brand         125690 non-null  int64
#  2   model_year    125690 non-null  int64
#  3   milage        125690 non-null  int64
#  4   fuel_type     125690 non-null  int64
#  5   transmission  125690 non-null  int64
#  6   accident      125690 non-null  int64
#  7   is_luxury     125690 non-null  int64
# dtypes: int64(8)
# memory usage: 7.7 MB

# %%
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      125690 non-null  int64
#  1   price   125690 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 1.9 MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 162610 entries, 0 to 188532
# Data columns (total 9 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            162610 non-null  int64
#  1   brand         162610 non-null  int64
#  2   model_year    162610 non-null  int64
#  3   milage        162610 non-null  int64
#  4   fuel_type     162610 non-null  int64
#  5   transmission  162610 non-null  int64
#  6   accident      162610 non-null  int64
#  7   price         162610 non-null  int64
#  8   is_luxury     162610 non-null  int64
# dtypes: int64(9)
# memory usage: 12.4 MB

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125690 entries, 0 to 125689
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            125690 non-null  int64
#  1   brand         125690 non-null  int64
#  2   model_year    125690 non-null  int64
#  3   milage        125690 non-null  int64
#  4   fuel_type     125690 non-null  int64
#  5   transmission  125690 non-null  int64
#  6   accident      125690 non-null  int64
#  7   is_luxury     125690 non-null  int64
# dtypes: int64(8)
# memory usage: 7.7 MB

# %%
# drop_col=['price']
# dt.drop( drop_col, inplace=True, axis=1)

# %%
# drop_col=['id']
# df.drop( drop_col, inplace=True, axis=1)

# %%
id = sf.pop('id')
y_pred = linear_reg.predict(dt)

# Create a submission DataFrame
submission_df = pd.DataFrame({
    'id': id,
    'class': y_pred
})

# Save the submission DataFrame to a CSV file
submission_df.to_csv('results.csv', index=False)
print("Submission file created: sample_submission.csv")
# Out:
# Submission file created: sample_submission.csv

# %%
sf
# Out:
#             price
# 0       43878.016
# 1       43878.016
# 2       43878.016
# 3       43878.016
# 4       43878.016
# ...           ...
# 125685  43878.016
# 125686  43878.016
# 125687  43878.016
# 125688  43878.016
# 125689  43878.016
#
# [125690 rows x 1 columns]
